# %% [markdown]
# Q. Write a Python program to reverse a word after accepting the input from the user.
# Sample Output:
# Input word: AcadGild
# Output: dilGdacA

# %%
Input_string= input("Enter a sentence: ")
print("Output string: ", Input_string[::-1])

# %% [markdown]
# ![Task%202_Q3.png](attachment:Task%202_Q3.png)
