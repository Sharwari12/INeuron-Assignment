# %% [markdown]
# Q. Write a Python Program to print the given string in the format specified in the sample output.
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
# SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all
# its citizens

# %%
Input_string="{}WE, THE PEOPLE OF INDIA,{}having solemnly resolved to constitute India into a SOVEREIGN,{}SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC {}and to secure to all its citizens"
print("Output string: ", Input_string.format('\n','\n\t','!\n\t\t','\n\t\t'))

# %% [markdown]
# ![Task%202_Q4.png](attachment:Task%202_Q4.png)
